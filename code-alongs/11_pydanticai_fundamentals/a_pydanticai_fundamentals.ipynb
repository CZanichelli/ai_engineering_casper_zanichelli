# %% [markdown]
# PydanticAI fundamentals

# %%
from pydantic_ai import Agent

agent = Agent(model="google-gla:gemini-2.5-flash")


result = await agent.run("give me a programming jokke")

result
# Out:
# ---------------------------------------------------------------------------
# UserError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from pydantic_ai import Agent
# ----> 3 agent = Agent(model="google-gla:gemini-2.5-flash")
#       6 result = await agent.run("give me a programming jokke")
#       8 result
#
# File c:\Users\Casper\Documents\ai_engineering_casper_zanichelli\ai_engineering_casper_zanichelli\.venv\Lib\site-packages\pydantic_ai\agent\__init__.py:325, in Agent.__init__(self, model, output_type, instructions, system_prompt, deps_type, name, model_settings, retries, validation_context, output_retries, tools, builtin_tools, prepare_tools, prepare_output_tools, toolsets, defer_model_check, end_strategy, instrument, metadata, history_processors, event_stream_handler, tool_timeout, **_deprecated_kwargs)
#     323     self._model = model
#     324 else:
# --> 325     self._model = models.infer_model(model)
#     327 self._name = name
#     328 self.end_strategy = end_strategy
#
# File c:\Users\Casper\Documents\ai_engineering_casper_zanichelli\ai_engineering_casper_zanichelli\.venv\Lib\site-packages\pydantic_ai\models\__init__.py:1106, in infer_model(model, provider_factory)
#    1100     warnings.warn(
#    1101         "The 'vertexai' provider name is deprecated. Use 'google-vertex' instead.",
#    1102         DeprecationWarning,
#    1103     )
#    1104     provider_name = 'google-vertex'
# -> 1106 provider = provider_factory(provider_name)
#    1108 model_kind = provider_name
#    1109 if model_kind.startswith('gateway/'):
#
# File c:\Users\Casper\Documents\ai_engineering_casper_zanichelli\ai_engineering_casper_zanichelli\.venv\Lib\site-packages\pydantic_ai\providers\__init__.py:174, in infer_provider(provider)
#     171 elif provider in ('google-vertex', 'google-gla'):
#     172     from .google import GoogleProvider
# --> 174     return GoogleProvider(vertexai=provider == 'google-vertex')
#     175 else:
#     176     provider_class = infer_provider_class(provider)
#
# File c:\Users\Casper\Documents\ai_engineering_casper_zanichelli\ai_engineering_casper_zanichelli\.venv\Lib\site-packages\pydantic_ai\providers\google.py:120, in GoogleProvider.__init__(self, api_key, credentials, project, location, vertexai, client, http_client, base_url)
#     118 if not vertexai:
#     119     if api_key is None:
# --> 120         raise UserError(
#     121             'Set the `GOOGLE_API_KEY` environment variable or pass it via `GoogleProvider(api_key=...)`'
#     122             'to use the Google Generative Language API.'
#     123         )
#     124     self._client = Client(vertexai=False, api_key=api_key, http_options=http_options)
#     125 else:
#
# UserError: Set the `GOOGLE_API_KEY` environment variable or pass it via `GoogleProvider(api_key=...)`to use the Google Generative Language API.

# %%
print(result.output)
# Out:
# Why do programmers prefer dark mode?
#
# Because light attracts bugs!

# %%
result = await agent.run("Give me an IT employee working in Sweden, shortly")

result
# Out:
# AgentRunResult(output="**Axel Lindgren**\n\n*   **Role:** Fullstack Developer\n*   **Location:** Stockholm, Sweden\n*   **Company:** Works for an innovative SaaS company, building web applications and backend services.\n*   **Skills:** Proficient in JavaScript (React, Node.js), Python, and cloud platforms like AWS.\n*   **Swedish Touch:** Values work-life balance, enjoys collaborative team environments, and always appreciates a good 'fika' break.")

# %%
print(result.output)
# Out:
# **Axel Lindgren**
#
# *   **Role:** Fullstack Developer
# *   **Location:** Stockholm, Sweden
# *   **Company:** Works for an innovative SaaS company, building web applications and backend services.
# *   **Skills:** Proficient in JavaScript (React, Node.js), Python, and cloud platforms like AWS.
# *   **Swedish Touch:** Values work-life balance, enjoys collaborative team environments, and always appreciates a good 'fika' break.

# %%
with open ("employee.md", "w") as file:
    file.write(result.output)

# %% [markdown]
# Pydantic to structure the output

# %%
from pydantic import BaseModel, Field

class EmployeeModel(BaseModel):
    name: str = Field (description="name of employee")
    age: int = Field (description="age of employee", gt = 17, lt=70)
    salary: int = Field (description="monthly salary of employee", gt = 35000, lt= 70000)
    role: str = Field (description="role of the employee, what he/she is working with")


result = await agent.run("Give me an IT employee working in Sweden, shortly", output_type = EmployeeModel)

result
# Out:
# AgentRunResult(output=EmployeeModel(name='John Doe', age=30, salary=40000, role='IT employee'))

# %%
employee = result.output
employee
# Out:
# EmployeeModel(name='John Doe', age=30, salary=40000, role='IT employee')

# %%
employee.name, employee.role
# Out:
# ('John Doe', 'IT employee')

# %%
isinstance(employee, EmployeeModel), isinstance(employee, BaseModel)
# Out:
# (True, True)

# %% [markdown]
# simulate more employee
