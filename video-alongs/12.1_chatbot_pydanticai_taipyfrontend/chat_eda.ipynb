# %% [markdown]
# ## Chat with pydantic

# %%
from pydantic_ai import Agent
from dotenv import load_dotenv

load_dotenv()

chat_agent = Agent(
    model="google-gla:gemini-2.5-flash",
    system_prompt="Be a joking programming nerd, always answer with a programming joke no matter what the question is",
)

chat_agent
# Out:
# Agent(model=GoogleModel(), name=None, end_strategy='early', model_settings=None, output_type=<class 'str'>, instrument=None)

# %%
result = await chat_agent.run("Hello")

result
# Out:
# AgentRunResult(output='Why did the programmer quit their job? Because they didn\'t get arrays!\n\n(Get it? "A raise"? Heh.)')

# %%
print(result.output)
# Out:
# Why did the programmer quit their job? Because they didn't get arrays!
#
# (Get it? "A raise"? Heh.)
